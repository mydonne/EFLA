# %% [markdown]
# # EFLA项目简介
# ## Extract-Feedback-Learn-Assess
# ![EFLA-1.png](attachment:EFLA-1.png)
# #### 功能：
# 1. 与网络地图API或视图连接，通过后台提取计算，在线实时地对框定区域进行预测；
# 2. 用户可对结果编辑修正，并反馈修正结果至后台；
# 3. 后台应用反馈的结果进行学习，并更新模型；
# 4. 建立评估机制：样本的评估分类及管理、模型的评估分类及管理。
